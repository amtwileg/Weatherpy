# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
size = 2_000
lats = np.random.uniform(low=-90.000, high=90.000, size=size)
lngs = np.random.uniform(low=-180.000, high=180.000, size=size)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=14415f0be7fe95e49cf9317557bd2b37

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather['weather'][-1]['description'],
                         })
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nova friburgo
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | codrington
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | ornskoldsvik
# Processing Record 13 of Set 1 | roseto degli abruzzi
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | taoudenni
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | teya
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | bodden town
# Processing Record 28 of Set 1 | quatre cocos
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | marsh harbour
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | singaparna
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | adolfo lopez mateos
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | asbury park
# Processing Record 39 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | kiunga
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | cognac
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | tahe
# Processing Record 49 of Set 1 | ystad
# Processing Record 50 of Set 1 | kununurra
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | sarangani
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | pisco
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | tete
# Processing Record 10 of Set 2 | namibe
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | necochea
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | tarime
# Processing Record 16 of Set 2 | heihe
# Processing Record 17 of Set 2 | tarija
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | temiscaming
# Processing Record 20 of Set 2 | monrovia
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | palmer
# Processing Record 23 of Set 2 | vardo
# Processing Record 24 of Set 2 | brae
# Processing Record 25 of Set 2 | zyryanka
# Processing Record 26 of Set 2 | laiyang
# Processing Record 27 of Set 2 | okhotsk
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | nchelenge
# Processing Record 30 of Set 2 | sao felix do xingu
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | olafsvik
# Processing Record 33 of Set 2 | ust-nera
# Processing Record 34 of Set 2 | santa cruz
# Processing Record 35 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 2 | daru
# Processing Record 37 of Set 2 | yaval
# Processing Record 38 of Set 2 | namatanai
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | budelsdorf
# Processing Record 41 of Set 2 | xinxiang
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | westport
# Processing Record 48 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 2 | dalmatovo
# Processing Record 50 of Set 2 | rorvik
# Processing Record 1 of Set 3 | zhezkazgan
# Processing Record 2 of Set 3 | royan
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | coihaique
# Processing Record 5 of Set 3 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 6 of Set 3 | aitape
# Processing Record 7 of Set 3 | areka
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | sivas
# Processing Record 10 of Set 3 | otjiwarongo
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | jalu
# Processing Record 13 of Set 3 | mamallapuram
# Processing Record 14 of Set 3 | atbasar
# Processing Record 15 of Set 3 | spornoye
# Processing Record 16 of Set 3 | jambi
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | bay roberts
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | maketu
# Processing Record 21 of Set 3 | huarmey
# Processing Record 22 of Set 3 | galdar
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | klaksvik
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | vanimo
# Processing Record 27 of Set 3 | aleksandrov gay
# Processing Record 28 of Set 3 | punta alta
# Processing Record 29 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 3 | birjand
# Processing Record 31 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 3 | cootamundra
# Processing Record 33 of Set 3 | paredon
# Processing Record 34 of Set 3 | atar
# Processing Record 35 of Set 3 | shelburne
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | karasjok
# Processing Record 39 of Set 3 | sinnamary
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | wisconsin rapids
# Processing Record 43 of Set 3 | saint thomas mount
# Processing Record 44 of Set 3 | kenai
# Processing Record 45 of Set 3 | antofagasta
# Processing Record 46 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 3 | roebourne
# Processing Record 48 of Set 3 | henderson
# Processing Record 49 of Set 3 | borama
# City not found. Skipping...
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | mehamn
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | flinders
# Processing Record 4 of Set 4 | cape town
# Processing Record 5 of Set 4 | ozu
# Processing Record 6 of Set 4 | kahului
# Processing Record 7 of Set 4 | felanitx
# Processing Record 8 of Set 4 | liverpool
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | miles city
# Processing Record 12 of Set 4 | simao
# Processing Record 13 of Set 4 | la serena
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | bathsheba
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | northam
# Processing Record 25 of Set 4 | padang
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | caramay
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | sept-iles
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | port lincoln
# Processing Record 33 of Set 4 | agadir
# Processing Record 34 of Set 4 | smithers
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | algarrobo
# Processing Record 37 of Set 4 | dikson
# Processing Record 38 of Set 4 | ribas do rio pardo
# Processing Record 39 of Set 4 | riyadh
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | ilulissat
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | khatanga
# Processing Record 44 of Set 4 | opelousas
# Processing Record 45 of Set 4 | chernushka
# Processing Record 46 of Set 4 | noumea
# Processing Record 47 of Set 4 | saint-joseph
# Processing Record 48 of Set 4 | port elizabeth
# Processing Record 49 of Set 4 | shellbrook
# Processing Record 50 of Set 4 | karratha
# Processing Record 1 of Set 5 | dhone
# Processing Record 2 of Set 5 | simpang
# Processing Record 3 of Set 5 | half moon bay
# Processing Record 4 of Set 5 | baturaja
# Processing Record 5 of Set 5 | halifax
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | linqiong
# Processing Record 8 of Set 5 | richards bay
# Processing Record 9 of Set 5 | cherskiy
# Processing Record 10 of Set 5 | medina
# Processing Record 11 of Set 5 | uch
# Processing Record 12 of Set 5 | alta floresta
# Processing Record 13 of Set 5 | nizwa
# Processing Record 14 of Set 5 | upice
# Processing Record 15 of Set 5 | kaputa
# Processing Record 16 of Set 5 | wanning
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | rawson
# Processing Record 19 of Set 5 | dukat
# Processing Record 20 of Set 5 | omboue
# Processing Record 21 of Set 5 | tumwater
# Processing Record 22 of Set 5 | makakilo city
# Processing Record 23 of Set 5 | bubaque
# Processing Record 24 of Set 5 | pativilca
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | ahipara
# Processing Record 27 of Set 5 | tura
# Processing Record 28 of Set 5 | xining
# Processing Record 29 of Set 5 | beisfjord
# Processing Record 30 of Set 5 | keti bandar
# Processing Record 31 of Set 5 | parana
# Processing Record 32 of Set 5 | bahia blanca
# Processing Record 33 of Set 5 | dalbandin
# Processing Record 34 of Set 5 | gravdal
# Processing Record 35 of Set 5 | kiruna
# Processing Record 36 of Set 5 | uyo
# Processing Record 37 of Set 5 | mahibadhoo
# Processing Record 38 of Set 5 | antalaha
# Processing Record 39 of Set 5 | soe
# Processing Record 40 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 41 of Set 5 | atambua
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | yuzhno-sukhokumsk
# Processing Record 44 of Set 5 | breyten
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | great falls
# Processing Record 47 of Set 5 | satipo
# Processing Record 48 of Set 5 | lazaro cardenas
# Processing Record 49 of Set 5 | kirpilskaya
# Processing Record 50 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 1 of Set 6 | katha
# City not found. Skipping...
# Processing Record 2 of Set 6 | margate
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | beringovskiy
# Processing Record 5 of Set 6 | vila velha
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | esperance
# Processing Record 8 of Set 6 | shostka
# Processing Record 9 of Set 6 | pevek
# Processing Record 10 of Set 6 | cockburn town
# Processing Record 11 of Set 6 | tiznit
# Processing Record 12 of Set 6 | broadford
# Processing Record 13 of Set 6 | marawi
# Processing Record 14 of Set 6 | saint-augustin
# Processing Record 15 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | chandbali
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | hami
# Processing Record 20 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 6 | marabba
# Processing Record 22 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 6 | bikaner
# Processing Record 24 of Set 6 | kamaishi
# Processing Record 25 of Set 6 | sur
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | jerome
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | puerto del rosario
# Processing Record 30 of Set 6 | san quintin
# Processing Record 31 of Set 6 | uglich
# Processing Record 32 of Set 6 | krasnoselkup
# Processing Record 33 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 35 of Set 6 | deputatskiy
# Processing Record 36 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 6 | pinotepa nacional
# Processing Record 38 of Set 6 | seddon
# Processing Record 39 of Set 6 | kloulklubed
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | souillac
# Processing Record 42 of Set 6 | coahuayana
# Processing Record 43 of Set 6 | nueva loja
# Processing Record 44 of Set 6 | gambela
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | bereda
# Processing Record 47 of Set 6 | kaspiyskiy
# Processing Record 48 of Set 6 | eyl
# Processing Record 49 of Set 6 | sinjai
# Processing Record 50 of Set 6 | tabalosos
# Processing Record 1 of Set 7 | ardabil
# Processing Record 2 of Set 7 | sobolevo
# Processing Record 3 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 7 | songjianghe
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | avera
# Processing Record 7 of Set 7 | det udom
# Processing Record 8 of Set 7 | hay river
# Processing Record 9 of Set 7 | muros
# Processing Record 10 of Set 7 | hovd
# Processing Record 11 of Set 7 | luganville
# Processing Record 12 of Set 7 | san cristobal
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | beidao
# Processing Record 15 of Set 7 | isangel
# Processing Record 16 of Set 7 | leh
# Processing Record 17 of Set 7 | jinchang
# Processing Record 18 of Set 7 | acapulco
# Processing Record 19 of Set 7 | biri
# Processing Record 20 of Set 7 | lons-le-saunier
# Processing Record 21 of Set 7 | dabhol
# Processing Record 22 of Set 7 | valle del guamuez
# Processing Record 23 of Set 7 | pangody
# Processing Record 24 of Set 7 | ranong
# Processing Record 25 of Set 7 | stranda
# Processing Record 26 of Set 7 | mandalgovi
# Processing Record 27 of Set 7 | shimanovsk
# Processing Record 28 of Set 7 | araouane
# Processing Record 29 of Set 7 | herat
# Processing Record 30 of Set 7 | djibo
# Processing Record 31 of Set 7 | pouembout
# Processing Record 32 of Set 7 | austin
# Processing Record 33 of Set 7 | zhigansk
# Processing Record 34 of Set 7 | meligalas
# Processing Record 35 of Set 7 | kamenka
# Processing Record 36 of Set 7 | lambarene
# Processing Record 37 of Set 7 | faanui
# Processing Record 38 of Set 7 | kasiri
# Processing Record 39 of Set 7 | samarai
# Processing Record 40 of Set 7 | nazas
# Processing Record 41 of Set 7 | ghanzi
# Processing Record 42 of Set 7 | guapore
# Processing Record 43 of Set 7 | ishigaki
# Processing Record 44 of Set 7 | bhadrachalam
# Processing Record 45 of Set 7 | reconquista
# Processing Record 46 of Set 7 | derbent
# Processing Record 47 of Set 7 | amarpur
# Processing Record 48 of Set 7 | udachnyy
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | vasilkovo
# City not found. Skipping...
# Processing Record 1 of Set 8 | tautira
# Processing Record 2 of Set 8 | moose factory
# Processing Record 3 of Set 8 | port hardy
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | merrill
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | kaitangata
# Processing Record 9 of Set 8 | del rio
# Processing Record 10 of Set 8 | tacuarembo
# Processing Record 11 of Set 8 | bredy
# Processing Record 12 of Set 8 | teeli
# Processing Record 13 of Set 8 | broken hill
# Processing Record 14 of Set 8 | edd
# Processing Record 15 of Set 8 | les escoumins
# Processing Record 16 of Set 8 | yumen
# Processing Record 17 of Set 8 | egvekinot
# Processing Record 18 of Set 8 | bridgetown
# Processing Record 19 of Set 8 | caravelas
# Processing Record 20 of Set 8 | phan thiet
# Processing Record 21 of Set 8 | ayan
# Processing Record 22 of Set 8 | borogontsy
# Processing Record 23 of Set 8 | pimenta bueno
# Processing Record 24 of Set 8 | dzhebariki-khaya
# Processing Record 25 of Set 8 | sola
# Processing Record 26 of Set 8 | kristianstad
# Processing Record 27 of Set 8 | marquette
# Processing Record 28 of Set 8 | vestmannaeyjar
# Processing Record 29 of Set 8 | novovarshavka
# Processing Record 30 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 8 | inuvik
# Processing Record 32 of Set 8 | dahanu
# Processing Record 33 of Set 8 | nangong
# Processing Record 34 of Set 8 | mapimi
# Processing Record 35 of Set 8 | mbouda
# Processing Record 36 of Set 8 | buraydah
# Processing Record 37 of Set 8 | yar-sale
# Processing Record 38 of Set 8 | selje
# Processing Record 39 of Set 8 | jilib
# Processing Record 40 of Set 8 | goundam
# Processing Record 41 of Set 8 | pafos
# Processing Record 42 of Set 8 | tchollire
# Processing Record 43 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 8 | poya
# Processing Record 45 of Set 8 | sembe
# Processing Record 46 of Set 8 | itarema
# Processing Record 47 of Set 8 | maltahohe
# Processing Record 48 of Set 8 | almaznyy
# Processing Record 49 of Set 8 | ambilobe
# Processing Record 50 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 1 of Set 9 | tanout
# Processing Record 2 of Set 9 | kaili
# Processing Record 3 of Set 9 | tabas
# Processing Record 4 of Set 9 | waddan
# Processing Record 5 of Set 9 | saint anthony
# Processing Record 6 of Set 9 | charters towers
# Processing Record 7 of Set 9 | beaumont
# Processing Record 8 of Set 9 | iquique
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | saint-pierre
# Processing Record 11 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 9 | portland
# Processing Record 13 of Set 9 | khandyga
# Processing Record 14 of Set 9 | san francisco
# Processing Record 15 of Set 9 | wajir
# Processing Record 16 of Set 9 | kvarkeno
# Processing Record 17 of Set 9 | iqaluit
# Processing Record 18 of Set 9 | sitka
# Processing Record 19 of Set 9 | salalah
# Processing Record 20 of Set 9 | vryburg
# Processing Record 21 of Set 9 | villa oliva
# City not found. Skipping...
# Processing Record 22 of Set 9 | umba
# Processing Record 23 of Set 9 | lata
# Processing Record 24 of Set 9 | vilhena
# Processing Record 25 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 9 | oborniki
# Processing Record 27 of Set 9 | kassala
# Processing Record 28 of Set 9 | maniitsoq
# Processing Record 29 of Set 9 | hammerfest
# Processing Record 30 of Set 9 | sambava
# Processing Record 31 of Set 9 | nokia
# Processing Record 32 of Set 9 | x-can
# City not found. Skipping...
# Processing Record 33 of Set 9 | ketchikan
# Processing Record 34 of Set 9 | lorengau
# Processing Record 35 of Set 9 | lerwick
# Processing Record 36 of Set 9 | aurora
# Processing Record 37 of Set 9 | lejanias
# Processing Record 38 of Set 9 | bonga
# Processing Record 39 of Set 9 | timberlake
# Processing Record 40 of Set 9 | kanigoro
# Processing Record 41 of Set 9 | rocha
# Processing Record 42 of Set 9 | the valley
# Processing Record 43 of Set 9 | koungou
# Processing Record 44 of Set 9 | emerald
# Processing Record 45 of Set 9 | znamenskoye
# Processing Record 46 of Set 9 | malpe
# Processing Record 47 of Set 9 | mareeba
# Processing Record 48 of Set 9 | merauke
# Processing Record 49 of Set 9 | gilgil
# City not found. Skipping...
# Processing Record 50 of Set 9 | arona
# Processing Record 1 of Set 10 | asyut
# Processing Record 2 of Set 10 | astorga
# Processing Record 3 of Set 10 | ancud
# Processing Record 4 of Set 10 | katherine
# Processing Record 5 of Set 10 | ambulu
# Processing Record 6 of Set 10 | seoul
# Processing Record 7 of Set 10 | grootfontein
# Processing Record 8 of Set 10 | ginda
# Processing Record 9 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 10 | bindura
# Processing Record 11 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 10 | muisne
# Processing Record 13 of Set 10 | maarianhamina
# Processing Record 14 of Set 10 | wasilla
# Processing Record 15 of Set 10 | nome
# Processing Record 16 of Set 10 | ambovombe
# Processing Record 17 of Set 10 | lieksa
# Processing Record 18 of Set 10 | biak
# Processing Record 19 of Set 10 | la sarre
# Processing Record 20 of Set 10 | labuhan
# Processing Record 21 of Set 10 | vaitape
# Processing Record 22 of Set 10 | severobaykalsk
# Processing Record 23 of Set 10 | galle
# Processing Record 24 of Set 10 | mattru
# Processing Record 25 of Set 10 | paamiut
# Processing Record 26 of Set 10 | te anau
# Processing Record 27 of Set 10 | talnakh
# Processing Record 28 of Set 10 | hervey bay
# Processing Record 29 of Set 10 | seydi
# Processing Record 30 of Set 10 | nuuk
# Processing Record 31 of Set 10 | bull savanna
# Processing Record 32 of Set 10 | santa isabel
# Processing Record 33 of Set 10 | cerrito
# Processing Record 34 of Set 10 | luderitz
# Processing Record 35 of Set 10 | manado
# Processing Record 36 of Set 10 | ozernovskiy
# Processing Record 37 of Set 10 | kupang
# Processing Record 38 of Set 10 | luau
# Processing Record 39 of Set 10 | lagoa
# Processing Record 40 of Set 10 | arrifes
# Processing Record 41 of Set 10 | uribia
# Processing Record 42 of Set 10 | anadyr
# Processing Record 43 of Set 10 | ugoofaaru
# Processing Record 44 of Set 10 | quanzhou
# Processing Record 45 of Set 10 | el alto
# Processing Record 46 of Set 10 | bima
# Processing Record 47 of Set 10 | puro
# Processing Record 48 of Set 10 | madisonville
# Processing Record 49 of Set 10 | hambantota
# Processing Record 50 of Set 10 | portobelo
# Processing Record 1 of Set 11 | nanakuli
# Processing Record 2 of Set 11 | eureka
# Processing Record 3 of Set 11 | matara
# Processing Record 4 of Set 11 | codo
# Processing Record 5 of Set 11 | cabatuan
# Processing Record 6 of Set 11 | byron bay
# Processing Record 7 of Set 11 | carutapera
# Processing Record 8 of Set 11 | lukiv
# Processing Record 9 of Set 11 | fort nelson
# Processing Record 10 of Set 11 | takoradi
# Processing Record 11 of Set 11 | fatehpur
# Processing Record 12 of Set 11 | navahrudak
# Processing Record 13 of Set 11 | pochutla
# Processing Record 14 of Set 11 | la ronge
# Processing Record 15 of Set 11 | elk city
# Processing Record 16 of Set 11 | upata
# Processing Record 17 of Set 11 | castanos
# Processing Record 18 of Set 11 | mangan
# Processing Record 19 of Set 11 | moose jaw
# Processing Record 20 of Set 11 | redmond
# Processing Record 21 of Set 11 | chongwe
# Processing Record 22 of Set 11 | viedma
# Processing Record 23 of Set 11 | novikovo
# Processing Record 24 of Set 11 | kalianget
# Processing Record 25 of Set 11 | itacare
# Processing Record 26 of Set 11 | pasighat
# Processing Record 27 of Set 11 | preobrazheniye
# Processing Record 28 of Set 11 | yelan-koleno
# Processing Record 29 of Set 11 | alekseyevka
# Processing Record 30 of Set 11 | banda aceh
# Processing Record 31 of Set 11 | fukue
# Processing Record 32 of Set 11 | rakhya
# City not found. Skipping...
# Processing Record 33 of Set 11 | bulgan
# Processing Record 34 of Set 11 | kita
# Processing Record 35 of Set 11 | azovskaya
# Processing Record 36 of Set 11 | los llanos de aridane
# Processing Record 37 of Set 11 | fort-shevchenko
# Processing Record 38 of Set 11 | esik
# Processing Record 39 of Set 11 | shimoda
# Processing Record 40 of Set 11 | seymchan
# Processing Record 41 of Set 11 | bonavista
# Processing Record 42 of Set 11 | emporia
# Processing Record 43 of Set 11 | anchorage
# Processing Record 44 of Set 11 | gravelbourg
# Processing Record 45 of Set 11 | williston
# Processing Record 46 of Set 11 | port blair
# Processing Record 47 of Set 11 | son la
# Processing Record 48 of Set 11 | deep river
# Processing Record 49 of Set 11 | poco verde
# Processing Record 50 of Set 11 | kanniyakumari
# Processing Record 1 of Set 12 | boa vista
# Processing Record 2 of Set 12 | palu
# Processing Record 3 of Set 12 | jablah
# Processing Record 4 of Set 12 | bathurst
# Processing Record 5 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 12 | hurghada
# Processing Record 7 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 12 | shu
# Processing Record 9 of Set 12 | outjo
# Processing Record 10 of Set 12 | bodoco
# City not found. Skipping...
# Processing Record 11 of Set 12 | novichikha
# Processing Record 12 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 13 of Set 12 | maseru
# Processing Record 14 of Set 12 | ust-ilimsk
# Processing Record 15 of Set 12 | manono
# Processing Record 16 of Set 12 | bonnyville
# Processing Record 17 of Set 12 | ossora
# Processing Record 18 of Set 12 | menongue
# Processing Record 19 of Set 12 | skovde
# City not found. Skipping...
# Processing Record 20 of Set 12 | tranas
# Processing Record 21 of Set 12 | luanda
# Processing Record 22 of Set 12 | pitimbu
# Processing Record 23 of Set 12 | nalut
# Processing Record 24 of Set 12 | mecca
# Processing Record 25 of Set 12 | tawau
# Processing Record 26 of Set 12 | manyana
# Processing Record 27 of Set 12 | olinda
# Processing Record 28 of Set 12 | verkhniy landekh
# Processing Record 29 of Set 12 | totness
# Processing Record 30 of Set 12 | nishihara
# Processing Record 31 of Set 12 | finnsnes
# Processing Record 32 of Set 12 | burgos
# Processing Record 33 of Set 12 | leningradskiy
# Processing Record 34 of Set 12 | port dickson
# Processing Record 35 of Set 12 | chateaubelair
# Processing Record 36 of Set 12 | acheng
# Processing Record 37 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | porec
# Processing Record 40 of Set 12 | vanavara
# Processing Record 41 of Set 12 | talara
# Processing Record 42 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 43 of Set 12 | saint-francois
# Processing Record 44 of Set 12 | masuguru
# Processing Record 45 of Set 12 | madera
# Processing Record 46 of Set 12 | khash
# Processing Record 47 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 12 | yinchuan
# Processing Record 49 of Set 12 | somerset east
# Processing Record 50 of Set 12 | codajas
# Processing Record 1 of Set 13 | usogorsk
# Processing Record 2 of Set 13 | tevriz
# Processing Record 3 of Set 13 | ureki
# Processing Record 4 of Set 13 | strezhevoy
# Processing Record 5 of Set 13 | along
# Processing Record 6 of Set 13 | trincomalee
# Processing Record 7 of Set 13 | colares
# Processing Record 8 of Set 13 | kyzyl-suu
# Processing Record 9 of Set 13 | kieta
# Processing Record 10 of Set 13 | sorland
# Processing Record 11 of Set 13 | mount isa
# Processing Record 12 of Set 13 | manacapuru
# Processing Record 13 of Set 13 | tecoanapa
# Processing Record 14 of Set 13 | valcourt
# Processing Record 15 of Set 13 | andenes
# Processing Record 16 of Set 13 | voznesenye
# Processing Record 17 of Set 13 | pangai
# Processing Record 18 of Set 13 | moree
# Processing Record 19 of Set 13 | rangpur
# Processing Record 20 of Set 13 | conceicao da barra
# Processing Record 21 of Set 13 | mercedes
# Processing Record 22 of Set 13 | high prairie
# Processing Record 23 of Set 13 | cap malheureux
# Processing Record 24 of Set 13 | chifeng
# Processing Record 25 of Set 13 | goba
# Processing Record 26 of Set 13 | nhulunbuy
# Processing Record 27 of Set 13 | mana
# Processing Record 28 of Set 13 | tual
# Processing Record 29 of Set 13 | fortuna
# Processing Record 30 of Set 13 | norden
# Processing Record 31 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 13 | lucapa
# Processing Record 33 of Set 13 | camocim
# Processing Record 34 of Set 13 | luwuk
# Processing Record 35 of Set 13 | tabuk
# Processing Record 36 of Set 13 | cam ranh
# Processing Record 37 of Set 13 | asau
# Processing Record 38 of Set 13 | grants pass
# Processing Record 39 of Set 13 | korla
# Processing Record 40 of Set 13 | laiagam
# City not found. Skipping...
# Processing Record 41 of Set 13 | asfi
# Processing Record 42 of Set 13 | ruteng
# Processing Record 43 of Set 13 | evensk
# Processing Record 44 of Set 13 | buala
# Processing Record 45 of Set 13 | burnie
# Processing Record 46 of Set 13 | huilong
# Processing Record 47 of Set 13 | camacha
# Processing Record 48 of Set 13 | manokwari
# Processing Record 49 of Set 13 | taltal
# Processing Record 50 of Set 13 | havre-saint-pierre
# Processing Record 1 of Set 14 | clovis
# Processing Record 2 of Set 14 | gamboma
# Processing Record 3 of Set 14 | maloy
# Processing Record 4 of Set 14 | bardiyah
# Processing Record 5 of Set 14 | amahai
# Processing Record 6 of Set 14 | wilmington
# Processing Record 7 of Set 14 | okha
# Processing Record 8 of Set 14 | west plains
# Processing Record 9 of Set 14 | nova esperanca
# Processing Record 10 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 11 of Set 14 | teguldet
# Processing Record 12 of Set 14 | hirara
# Processing Record 13 of Set 14 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 14 of Set 14 | zunheboto
# Processing Record 15 of Set 14 | roblin
# Processing Record 16 of Set 14 | balkanabat
# Processing Record 17 of Set 14 | rock springs
# Processing Record 18 of Set 14 | keetmanshoop
# Processing Record 19 of Set 14 | ixtapa
# Processing Record 20 of Set 14 | zadar
# Processing Record 21 of Set 14 | izumo
# Processing Record 22 of Set 14 | rosetta
# Processing Record 23 of Set 14 | sorong
# Processing Record 24 of Set 14 | sokoto
# Processing Record 25 of Set 14 | hobyo
# Processing Record 26 of Set 14 | price
# Processing Record 27 of Set 14 | puerto leguizamo
# Processing Record 28 of Set 14 | dalvik
# Processing Record 29 of Set 14 | inhambane
# Processing Record 30 of Set 14 | frontignan
# Processing Record 31 of Set 14 | najran
# Processing Record 32 of Set 14 | dhidhdhoo
# Processing Record 33 of Set 14 | maumere
# Processing Record 34 of Set 14 | belyy yar
# Processing Record 35 of Set 14 | tazovskiy
# Processing Record 36 of Set 14 | hofn
# Processing Record 37 of Set 14 | atocha
# Processing Record 38 of Set 14 | tambacounda
# Processing Record 39 of Set 14 | lavumisa
# Processing Record 40 of Set 14 | ambon
# Processing Record 41 of Set 14 | erenhot
# Processing Record 42 of Set 14 | algiers
# Processing Record 43 of Set 14 | tesistan
# Processing Record 44 of Set 14 | khuzdar
# Processing Record 45 of Set 14 | chumikan
# Processing Record 46 of Set 14 | praia
# Processing Record 47 of Set 14 | bloemfontein
# Processing Record 48 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 14 | wabag
# Processing Record 50 of Set 14 | moerai
# Processing Record 1 of Set 15 | shajapur
# Processing Record 2 of Set 15 | adre
# Processing Record 3 of Set 15 | narbonne
# Processing Record 4 of Set 15 | nyurba
# Processing Record 5 of Set 15 | vostok
# Processing Record 6 of Set 15 | sistranda
# Processing Record 7 of Set 15 | chichigalpa
# Processing Record 8 of Set 15 | fairbanks
# Processing Record 9 of Set 15 | praia da vitoria
# Processing Record 10 of Set 15 | moses lake
# Processing Record 11 of Set 15 | artyom
# Processing Record 12 of Set 15 | batagay-alyta
# Processing Record 13 of Set 15 | grand island
# Processing Record 14 of Set 15 | castelo do piaui
# Processing Record 15 of Set 15 | namie
# Processing Record 16 of Set 15 | amapa
# Processing Record 17 of Set 15 | monte alegre
# Processing Record 18 of Set 15 | luba
# Processing Record 19 of Set 15 | itamaraca
# Processing Record 20 of Set 15 | santo tomas
# Processing Record 21 of Set 15 | ibitinga
# Processing Record 22 of Set 15 | baft
# Processing Record 23 of Set 15 | gat
# Processing Record 24 of Set 15 | labuan
# Processing Record 25 of Set 15 | havelock
# Processing Record 26 of Set 15 | penaflor
# Processing Record 27 of Set 15 | douentza
# Processing Record 28 of Set 15 | cristalina
# Processing Record 29 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 15 | port hedland
# Processing Record 31 of Set 15 | dunedin
# Processing Record 32 of Set 15 | berlevag
# Processing Record 33 of Set 15 | rachitoasa
# Processing Record 34 of Set 15 | riosucio
# Processing Record 35 of Set 15 | parintins
# Processing Record 36 of Set 15 | el tigre
# Processing Record 37 of Set 15 | diveyevo
# Processing Record 38 of Set 15 | willowmore
# Processing Record 39 of Set 15 | cuiluan
# Processing Record 40 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 15 | marzuq
# Processing Record 42 of Set 15 | awjilah
# Processing Record 43 of Set 15 | axim
# Processing Record 44 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 15 | grindavik
# Processing Record 46 of Set 15 | tulsipur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Nova Friburgo      BR -22.2819  -42.5311     74.19        69          30
# 1    Saint George      US  37.1041 -113.5841     59.79        30           0
# 2     Yellowknife      CA  62.4560 -114.3525     19.92        68           0
# 3          Castro      BR -24.7911  -50.0119     75.45        61          39
# 4           Kapaa      US  22.0752 -159.3190     75.18        83          88
# 5      Codrington      AU -38.2667  141.9667     48.58        93           1
# 6     Port Alfred      ZA -33.5906   26.8910     61.18        83          98
# 7  Ribeira Grande      PT  38.5167  -28.7000     63.00        59          40
# 8       Busselton      AU -33.6500  115.3333     63.82        51         100
# 9    Ornskoldsvik      SE  63.2909   18.7153     47.35        49          16
#
#    Wind Speed Current Description
# 0        0.94    scattered clouds
# 1        3.44           clear sky
# 2       12.66           clear sky
# 3        2.26    scattered clouds
# 4        5.99     overcast clouds
# 5        7.52           clear sky
# 6        5.01     overcast clouds
# 7       18.41    scattered clouds
# 8        9.84     overcast clouds
# 9        8.05          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
